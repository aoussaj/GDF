# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, roc_auc_score, classification_report
df = pd.read_csv("heart_failure_clinical_records_dataset.csv")

# %%
# First 5 rows
df.head()

# Basic info: column types, missing values
df.info()

# Summary statistics for numeric features
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB
# ...

# %%
df_two  = df[df["age"] >= 42]
df_two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 291 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       291 non-null    float64
#  1   anaemia                   291 non-null    int64
#  2   creatinine_phosphokinase  291 non-null    int64
#  3   diabetes                  291 non-null    int64
#  4   ejection_fraction         291 non-null    int64
#  5   high_blood_pressure       291 non-null    int64
#  6   platelets                 291 non-null    float64
#  7   serum_creatinine          291 non-null    float64
#  8   serum_sodium              291 non-null    int64
#  9   sex                       291 non-null    int64
#  10  smoking                   291 non-null    int64
#  11  time                      291 non-null    int64
#  12  DEATH_EVENT               291 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 31.8 KB

# %%
X_data = df_two.drop(["DEATH_EVENT","time"], axis=1)
y_data = df_two["DEATH_EVENT"]

# %%
print(df["sex"].unique())
print(df["smoking"].unique())
# Out:
# [1 0]
# [0 1]

# %%
X_numeric = X_data[["age", "creatinine_phosphokinase", "ejection_fraction",
               "platelets", "serum_creatinine", "serum_sodium"]]
scaler = MinMaxScaler()
X_numeric_scaled = scaler.fit_transform(X_numeric)

# %%
X_data[["age", "creatinine_phosphokinase", "ejection_fraction",
        "platelets", "serum_creatinine", "serum_sodium"]] = X_numeric_scaled

# Check the result
print(X_data.head())
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  0.622642        0                  0.071319         0           0.090909
# 1  0.245283        0                  1.000000         0           0.363636
# 2  0.433962        0                  0.015693         0           0.090909
# 3  0.150943        1                  0.011227         0           0.090909
# 4  0.433962        1                  0.017479         1           0.090909
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1   0.290823          0.157303      0.485714    1
# 1                    0   0.288833          0.067416      0.657143    1
# 2                    0   0.165960          0.089888      0.457143    1
# 3                    0   0.224148          0.157303      0.685714    1
# 4                    0   0.365984          0.247191      0.085714    0
#
#    smoking
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data,y_data,test_size=0.2,random_state=42)

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
y_prob = model.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_prob)

# %%
y_prob = model.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_prob)
print("ROC-AUC:", roc_auc)
# Out:
# ROC-AUC: 0.788647342995169
